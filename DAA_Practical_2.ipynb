# %% [markdown]
# ##**Linear Search**

# %%
import time

# Linear Search Function
def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1

# User input
n = int(input("Enter the number of elements: "))

arr = []
print(f"Enter {n} elements:")
for i in range(n):
    arr.append(int(input()))

key = int(input("Enter the element to search: "))

# Start timer
start_time = time.perf_counter()

# Perform Linear Search
index = linear_search(arr, key)

# Stop timer
end_time = time.perf_counter()

# Display result
if index != -1:
    print("\nElement found at index", index)
else:
    print("\nElement not found")

# Execution time
print(f"\nExecution Time: {(end_time - start_time) * 1_000_000:.2f} microseconds")

# Time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter 5 elements:
# 25
# 26
# 5
# 10
# 30
# Enter the element to search: 5
#
# Element found at index 2
#
# Execution Time: 81.86 microseconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
# Space Complexity: O(1)

# %% [markdown]
# ##**Binary Search**

# %%
import time

# Binary Search Function
def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1

# User input
n = int(input("Enter the number of elements: "))

arr = []
print(f"Enter {n} elements (in sorted order):")
for i in range(n):
    arr.append(int(input()))

key = int(input("Enter the element to search: "))

# Start timer
start_time = time.perf_counter()

# Perform Binary Search
index = binary_search(arr, key)

# Stop timer
end_time = time.perf_counter()

# Display result
if index != -1:
    print("\nElement found at index", index)
else:
    print("\nElement not found")

# Execution time
print(f"\nExecution Time: {(end_time - start_time) * 1_000_000:.2f} microseconds")

# Time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter 5 elements (in sorted order):
# 15
# 6
# 25
# 30
# 66
# Enter the element to search: 30
#
# Element found at index 3
#
# Execution Time: 86.45 microseconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
# Space Complexity: O(1)
