# %% [markdown]
# <a href="https://colab.research.google.com/github/anvesh-2530/DAA--LAB/blob/main/DAA_Practical_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Practical-4**

# %% [markdown]
# ##**Iterative Factorial**

# %%
import time

# Iterative Factorial Function
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# User Input
n = int(input("Enter a non-negative integer: "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")
else:
    # Start timer
    start_time = time.perf_counter_ns()

    # Calculate factorial
    result = factorial_iterative(n)

    # Stop timer
    end_time = time.perf_counter_ns()

    # Calculate execution time
    execution_time = end_time - start_time

    # Display result
    print(f"\n--- Iterative Factorial for {n}! ---")
    print("Factorial Result :", result)
    print("Execution Time   :", execution_time, "ns")

    # Time and Space Complexity
    print("\nTime Complexity:")
    print("O(n)")

    print("Space Complexity:")
    print("O(1)")
# Out:
# Enter a non-negative integer: 25
#
# --- Iterative Factorial for 25! ---
# Factorial Result : 15511210043330985984000000
# Execution Time   : 9210 ns
#
# Time Complexity:
# O(n)
# Space Complexity:
# O(1)

# %% [markdown]
# ##**Recursive Factorial**

# %%
import time

# Recursive Factorial Function
def factorial_recursive(n):
    if n <= 1:
        return 1

    return n * factorial_recursive(n - 1)


# User Input
n = int(input("Enter a non-negative integer: "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")
else:
    # Start timer
    start_time = time.perf_counter_ns()

    # Calculate factorial
    result = factorial_recursive(n)

    # Stop timer
    end_time = time.perf_counter_ns()

    # Calculate execution time
    execution_time = end_time - start_time

    # Display result
    print(f"\n--- Recursive Factorial for {n}! ---")
    print("Factorial Result :", result)
    print("Execution Time   :", execution_time, "ns")

    # Time and Space Complexity
    print("\nTime Complexity:")
    print("O(n)")

    print("Space Complexity:")
    print("O(n)")
# Out:
# Enter a non-negative integer: 30
#
# --- Recursive Factorial for 30! ---
# Factorial Result : 265252859812191058636308480000000
# Execution Time   : 7252 ns
#
# Time Complexity:
# O(n)
# Space Complexity:
# O(n)
