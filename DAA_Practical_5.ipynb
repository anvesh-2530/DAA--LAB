# %% [markdown]
# <a href="https://colab.research.google.com/github/anvesh-2530/DAA--LAB/blob/main/DAA_Practical_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**PRACTICAL 5**

# %%
# 0/1 Knapsack Problem using Dynamic Programming

# Given weights and values
weights = [2, 3, 4, 5, 6]
values = [20, 30, 35, 45, 50]

# Maximum capacity of knapsack
capacity = 10

n = len(weights)

# Create DP table
dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

# Dynamic Programming
for i in range(1, n + 1):
    for w in range(1, capacity + 1):

        if weights[i - 1] <= w:
            dp[i][w] = max(
                values[i - 1] + dp[i - 1][w - weights[i - 1]],
                dp[i - 1][w]
            )
        else:
            dp[i][w] = dp[i - 1][w]

# Display input
print("Weights:", weights)
print("Values :", values)
print("Capacity:", capacity)

# Display result
print("\nMaximum Profit:", dp[n][capacity])
# Out:
# Weights: [2, 3, 4, 5, 6]
# Values : [20, 30, 35, 45, 50]
# Capacity: 10
#
# Maximum Profit: 95
